# %%
import GetOldTweets3 as got
import pandas as pd
import datetime as dt

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

import re
import time

stopWords = set(stopwords.words('english'))

# %%
username = '@JoeBiden'
startDate = "2020-05-12"
endDate = "2020-05-19"

# %%
tweetCriteria = got.manager.TweetCriteria().setUsername(username).setSince(startDate).setUntil(endDate)
tweets = got.manager.TweetManager.getTweets(tweetCriteria)

# %%
df = pd.DataFrame([tweet.__dict__ for tweet in tweets])
originalDF = df

df = df.drop([], axis=1)

# %%
df.sample(3)
# Out:
#     username               to  \
# 58  JoeBiden  realDonaldTrump
# 45  JoeBiden              NPR
# 16  JoeBiden             None
#
#                                                  text  retweets  favorites  \
# 58              That’s the plan. http://IWillVote.com     23430     128870
# 45  Moments of crisis require swift and decisive a...      4982      18009
# 16  We need a president who puts hardworking Ameri...      4079      16299
#
#     replies                   id  \
# 58     5095  1260267215921844225
# 45     1418  1260733099652022273
# 16     2032  1261760080422322176
#
#                                             permalink  author_id  \
# 58  https://twitter.com/JoeBiden/status/1260267215...     939091
# 45  https://twitter.com/JoeBiden/status/1260733099...     939091
# 16  https://twitter.com/JoeBiden/status/1261760080...     939091
#
#                         date                  formatted_date hashtags  \
# 58 2020-05-12 17:54:53+00:00  Tue May 12 17:54:53 +0000 2020
# 45 2020-05-14 00:46:08+00:00  Thu May 14 00:46:08 +0000 2020
# 16 2020-05-16 20:47:00+00:00  Sat May 16 20:47:00 +0000 2020
#
#    mentions geo                                               urls
# 58               http://IWillVote.com,https://twitter.com/realD...
# 45               https://twitter.com/NPR/status/126040338410607...
# 16

# %% [markdown]
# ## Finding number of important words (keywords)

# %%
# This function  returns count of nouns, verbs, aadjectives, adverbs in the given tweet
def getkeywordCount(tweet):
    # Remove non alphanumeric characters 
    tweet = re.sub(r'[^\w]', ' ', tweet)
    # make tokens
    wordTokens = word_tokenize(tweet)
    # remove stopwords &
    # perform lemmatisation 
    lemmatizer = WordNetLemmatizer() 
    filtered = [lemmatizer.lemmatize(w) for w in wordTokens if not w in stopWords]
    # tag parts of speech
    tagged = nltk.pos_tag(filtered)
    keywords = [w[0] for w in tagged if w[1][0] in ["N", "J", "V", "R"]]
    return len(keywords)

# %%
df['keywordCount'] = df.apply(lambda x : getkeywordCount(x["text"]), axis=1)

# %%
df.sample(3)
# Out:
#     username    to                                               text  \
# 45  JoeBiden   NPR  Moments of crisis require swift and decisive a...
# 59  JoeBiden  None  Here's the deal: We can choose who our country...
# 20  JoeBiden  None                              Science over fiction.
#
#     retweets  favorites  replies                   id  \
# 45      4982      18009     1418  1260733099652022273
# 59     11332      53361     4275  1260225720435032065
# 20     22560     163707    13255  1261665206184312838
#
#                                             permalink  author_id  \
# 45  https://twitter.com/JoeBiden/status/1260733099...     939091
# 59  https://twitter.com/JoeBiden/status/1260225720...     939091
# 20  https://twitter.com/JoeBiden/status/1261665206...     939091
#
#                         date                  formatted_date hashtags  \
# 45 2020-05-14 00:46:08+00:00  Thu May 14 00:46:08 +0000 2020
# 59 2020-05-12 15:10:00+00:00  Tue May 12 15:10:00 +0000 2020
# 20 2020-05-16 14:30:00+00:00  Sat May 16 14:30:00 +0000 2020
#
#    mentions geo                                               urls  \
# 45               https://twitter.com/NPR/status/126040338410607...
# 59
# 20
#
#     keywordCount
# 45            19
# 59            16
# 20             2

# %% [markdown]
# ## Normalise the columns

# %%
for feature in ["retweets", "favorites", "replies", 'keywordCount']:
    df[feature+"NormalisedCount"] = df[feature]/(df[feature].max())#-df[feature].min())

# %%
df.sample(3)
# Out:
#     username               to  \
# 58  JoeBiden  realDonaldTrump
# 34  JoeBiden             None
# 12  JoeBiden             None
#
#                                                  text  retweets  favorites  \
# 58              That’s the plan. http://IWillVote.com     23430     128870
# 34  Donald Trump can deflect and shift blame all h...     14149      37688
# 12  Today, on the International Day Against Homoph...      8979      40872
#
#     replies                   id  \
# 58     5095  1260267215921844225
# 34     3054  1261070033905577985
# 12     1828  1262021805180506117
#
#                                             permalink  author_id  \
# 58  https://twitter.com/JoeBiden/status/1260267215...     939091
# 34  https://twitter.com/JoeBiden/status/1261070033...     939091
# 12  https://twitter.com/JoeBiden/status/1262021805...     939091
#
#                         date                  formatted_date  hashtags  \
# 58 2020-05-12 17:54:53+00:00  Tue May 12 17:54:53 +0000 2020
# 34 2020-05-14 23:05:00+00:00  Thu May 14 23:05:00 +0000 2020
# 12 2020-05-17 14:07:00+00:00  Sun May 17 14:07:00 +0000 2020  #IDAHOTB
#
#    mentions geo                                               urls  \
# 58               http://IWillVote.com,https://twitter.com/realD...
# 34
# 12               https://medium.com/@JoeBiden/statement-by-vice...
#
#     keywordCount  retweetsNormalisedCount  favoritesNormalisedCount  \
# 58             4                 0.576384                  0.512779
# 34            17                 0.348069                  0.149962
# 12            22                 0.220886                  0.162631
#
#     repliesNormalisedCount  keywordCountNormalisedCount
# 58                0.177917                     0.105263
# 34                0.106645                     0.447368
# 12                0.063834                     0.578947

# %% [markdown]
# ## Find out if the tweet is a retweet to some other persons tweet
# #### We do this because retweeted tweets get a far greater reach and thus skews the scores

# %%
df["ifTo"] = df.apply(lambda x: 0.6 if x["to"] else 1,axis = 1)

# %%
df.sample(3)
# Out:
#     username    to                                               text  \
# 20  JoeBiden  None                              Science over fiction.
# 42  JoeBiden  None  Happy Birthday to the one and only @StevieWonder.
# 3   JoeBiden  None  Donald Trump is the most corrupt president in ...
#
#     retweets  favorites  replies                   id  \
# 20     22560     163707    13255  1261665206184312838
# 42      2106      18265      700  1260764765556740098
# 3      37786     206478    28637  1262420180690505733
#
#                                             permalink  author_id  \
# 20  https://twitter.com/JoeBiden/status/1261665206...     939091
# 42  https://twitter.com/JoeBiden/status/1260764765...     939091
# 3   https://twitter.com/JoeBiden/status/1262420180...     939091
#
#                         date  ... hashtags       mentions geo urls  \
# 20 2020-05-16 14:30:00+00:00  ...
# 42 2020-05-14 02:51:58+00:00  ...           @StevieWonder
# 3  2020-05-18 16:30:00+00:00  ...
#
#    keywordCount  retweetsNormalisedCount  favoritesNormalisedCount  \
# 20            2                 0.554982                  0.651396
# 42            3                 0.051808                  0.072677
# 3            12                 0.929545                  0.821584
#
#     repliesNormalisedCount  keywordCountNormalisedCount  ifTo
# 20                0.462863                     0.052632   1.0
# 42                0.024444                     0.078947   1.0
# 3                 1.000000                     0.315789   1.0
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Get time elapsed since every tweet.
# ### We hypothise that older tweets get more exposure

# %%
df["formatted_date"] = df.apply(lambda x: x["formatted_date"][:-10]+x["formatted_date"][-4:], axis=1)

df["timeElapsedHours"] = df.apply(lambda x: (pd.Timestamp(endDate) - pd.to_datetime(x["formatted_date"])).total_seconds()//3600, axis = 1 )

df["timeElapsedScore"] = 1+0.04*(7*12-df["timeElapsedHours"])/7/24

# %% [markdown]
# ## Assign Score to tweet on basis of normalised count of retweets, favorites, replies, keyword count and time Elapsed

# %%
df["score"] = (1.5*df["retweetsNormalisedCount"] + 1.2*df["repliesNormalisedCount"] + 1*df["favoritesNormalisedCount"] + 2*df["keywordCount"])*df["ifTo"]*df["timeElapsedScore"]

# %%
sortedDF = df.sort_values(by=['score'], inplace=False,  ascending=False)

# %%
sortedDF.head(5)
# Out:
#     username    to                                               text  \
# 25  JoeBiden  None  Los fracasos internacionales de Trump han abie...
# 26  JoeBiden  None  Trump's international failures have cleared a ...
# 8   JoeBiden  None  As we reflect on the incredible legacy of Brow...
# 6   JoeBiden  None  A year ago today, the House passed the #Equali...
# 1   JoeBiden  None  - Expand vote-by-mail and early voting - Imple...
#
#     retweets  favorites  replies                   id  \
# 25      1293       5126     1468  1261404739109113856
# 26      6525      32228     6326  1261403984100818944
# 8       6168      30730     1360  1262133289982164992
# 6       6838      26338     1103  1262171039863394305
# 1       9191      37622     2820  1262480579624235008
#
#                                             permalink  author_id  \
# 25  https://twitter.com/JoeBiden/status/1261404739...     939091
# 26  https://twitter.com/JoeBiden/status/1261403984...     939091
# 8   https://twitter.com/JoeBiden/status/1262133289...     939091
# 6   https://twitter.com/JoeBiden/status/1262171039...     939091
# 1   https://twitter.com/JoeBiden/status/1262480579...     939091
#
#                         date  ... urls keywordCount retweetsNormalisedCount  \
# 25 2020-05-15 21:15:00+00:00  ...                38                0.031808
# 26 2020-05-15 21:12:00+00:00  ...                27                0.160517
# 8  2020-05-17 21:30:00+00:00  ...                26                0.151734
# 6  2020-05-18 00:00:00+00:00  ...                25                0.168216
# 1  2020-05-18 20:30:00+00:00  ...                24                0.226101
#
#    favoritesNormalisedCount repliesNormalisedCount  \
# 25                 0.020397               0.051262
# 26                 0.128236               0.220903
# 8                  0.122276               0.047491
# 6                  0.104800               0.038517
# 1                  0.149699               0.098474
#
#     keywordCountNormalisedCount  ifTo  timeElapsedHours  timeElapsedScore  \
# 25                     1.000000   1.0              74.0          1.002381
# 26                     0.710526   1.0              74.0          1.002381
# 8                      0.684211   1.0              26.0          1.013810
# 6                      0.657895   1.0              24.0          1.014286
# 1                      0.631579   1.0               3.0          1.019286
#
#         score
# 25  76.310885
# 26  54.764176
# 8   53.130580
# 6   51.123392
# 1   49.544441
#
# [5 rows x 24 columns]

# %%
# finalDF = sortedDF.drop(['to', 'retweets', 'favorites', 'replies', 'date',
#        'hashtags', 'mentions', 'geo', 'urls', 'keywordCount',
#        'ifTo', 'timeElapsedHours', 'timeElapsedScore'], axis = 1)

# finalDF.head(5).to_csv("JoeBiden.csv", index = False)

# %%
tweetsDF = sortedDF.head(5)

# %%
tweetsDF.columns
# Out:
# Index(['username', 'to', 'text', 'retweets', 'favorites', 'replies', 'id',
#        'permalink', 'author_id', 'date', 'formatted_date', 'hashtags',
#        'mentions', 'geo', 'urls', 'keywordCount', 'retweetsNormalisedCount',
#        'favoritesNormalisedCount', 'repliesNormalisedCount',
#        'keywordCountNormalisedCount', 'ifTo', 'timeElapsedHours',
#        'timeElapsedScore', 'score'],
#       dtype='object')

# %%
tweetsList = []
for i, row in df.iterrows():
    d = {}
    d['username'] = row['username']
    d['date'] = row['formatted_date']
    d['replies'] = row['replies']
    d['retweets'] = row['retweets']
    d['favorites'] = row['favorites']
    d['text'] = d['text']
    tweetsList.append(d)

# %%
tweetsList
# Out:
# [{'username': 'JoeBiden',
#   'date': 'Fri May 15 21:15:00 2020',
#   'replies': 1468,
#   'retweets': 1293,
#   'favorites': 5126},
#  {'username': 'JoeBiden',
#   'date': 'Fri May 15 21:12:00 2020',
#   'replies': 6326,
#   'retweets': 6525,
#   'favorites': 32228},
#  {'username': 'JoeBiden',
#   'date': 'Sun May 17 21:30:00 2020',
#   'replies': 1360,
#   'retweets': 6168,
#   'favorites': 30730},
#  {'username': 'JoeBiden',
#   'date': 'Mon May 18 00:00:00 2020',
#   'replies': 1103,
#   'retweets': 6838,
#   'favorites': 26338},
#  {'username': 'JoeBiden',
#   'date': 'Mon May 18 20:30:00 2020',
#   'replies': 2820,
#   'retweets': 9191,
#   'favorites': 37622}]
